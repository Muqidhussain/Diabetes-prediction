# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# %%
# Read the dataset
df = pd.read_csv('/kaggle/input/diabetes-prediction-dataset/diabetes_prediction_dataset.csv')

# Data preprocessing
encoder = LabelEncoder()
df['gender'] = encoder.fit_transform(df['gender'])
df['smoking_history'] = encoder.fit_transform(df['smoking_history'])

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop("diabetes", axis=1), df["diabetes"], test_size=0.2, random_state=42)

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import confusion_matrix

# Suppress ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# Logistic Regression
model_lr = LogisticRegression(max_iter=1000)  # Increase max_iter to avoid convergence warning
model_lr.fit(X_train, y_train)
pred_lr = model_lr.predict(X_test)
accuracy_lr = accuracy_score(y_test, pred_lr)
print("Logistic Regression Accuracy: {:.2%}".format(accuracy_lr))

# Confusion Matrix
cm_lr = confusion_matrix(y_test, pred_lr)
print("Confusion Matrix:")
print(cm_lr)
# Out:
# Logistic Regression Accuracy: 95.88%
# Confusion Matrix:
# [[18128   164]
#  [  660  1048]]

# %%
from sklearn.metrics import confusion_matrix

# SVM
model_svm = SVC()
model_svm.fit(X_train, y_train)
pred_svm = model_svm.predict(X_test)
accuracy_svm = accuracy_score(y_test, pred_svm)
print("SVM Accuracy: {:.2%}".format(accuracy_svm))

# Confusion Matrix
cm_svm = confusion_matrix(y_test, pred_svm)
print("Confusion Matrix:")
print(cm_svm)
# Out:
# SVM Accuracy: 94.73%
# Confusion Matrix:
# [[18292     0]
#  [ 1053   655]]

# %%
from sklearn.metrics import confusion_matrix

# Naïve Bayes
model_nb = GaussianNB()
model_nb.fit(X_train, y_train)
pred_nb = model_nb.predict(X_test)
accuracy_nb = accuracy_score(y_test, pred_nb)
print("Naïve Bayes Accuracy: {:.2%}".format(accuracy_nb))

# Confusion Matrix
cm_nb = confusion_matrix(y_test, pred_nb)
print("Confusion Matrix:")
print(cm_nb)
# Out:
# Naïve Bayes Accuracy: 90.48%
# Confusion Matrix:
# [[17005  1287]
#  [  618  1090]]

# %%
from sklearn.metrics import confusion_matrix

# Decision Tree
model_dt = DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
pred_dt = model_dt.predict(X_test)
accuracy_dt = accuracy_score(y_test, pred_dt)
print("Decision Tree Accuracy: {:.2%}".format(accuracy_dt))

# Confusion Matrix
cm_dt = confusion_matrix(y_test, pred_dt)
print("Confusion Matrix:")
print(cm_dt)
# Out:
# Decision Tree Accuracy: 95.30%
# Confusion Matrix:
# [[17801   491]
#  [  448  1260]]

# %%
from sklearn.metrics import confusion_matrix

# Random Forest
model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
pred_rf = model_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, pred_rf)
print("Random Forest Accuracy: {:.2%}".format(accuracy_rf))

# Confusion Matrix
cm_rf = confusion_matrix(y_test, pred_rf)
print("Confusion Matrix:")
print(cm_rf)
# Out:
# Random Forest Accuracy: 96.97%
# Confusion Matrix:
# [[18219    73]
#  [  532  1176]]

# %%
from sklearn.metrics import confusion_matrix

# Neural Networks
model_nn = MLPClassifier()
model_nn.fit(X_train, y_train)
pred_nn = model_nn.predict(X_test)
accuracy_nn = accuracy_score(y_test, pred_nn)
print("Neural Networks Accuracy: {:.2%}".format(accuracy_nn))

# Confusion Matrix
cm_nn = confusion_matrix(y_test, pred_nn)
print("Confusion Matrix:")
print(cm_nn)
# Out:
# Neural Networks Accuracy: 95.99%
# Confusion Matrix:
# [[18256    36]
#  [  765   943]]

# %%
# Import necessary libraries
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# Assuming you have already defined and initialized X_train, X_test, and y_test

# K-means Clustering
kmeans = KMeans(n_clusters=2)
kmeans.fit(X_train)
pred_kmeans = kmeans.predict(X_test)
accuracy_kmeans = accuracy_score(y_test, pred_kmeans)
print("K-means Clustering Accuracy: {:.2%}".format(accuracy_kmeans))
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# K-means Clustering Accuracy: 49.32%

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Logistic Regression
cm_lr = confusion_matrix(y_test, pred_lr)
print("Confusion Matrix - Logistic Regression:")
print(cm_lr)
print("\nClassification Report - Logistic Regression:")
print(classification_report(y_test, pred_lr))

# SVM
cm_svm = confusion_matrix(y_test, pred_svm)
print("Confusion Matrix - SVM:")
print(cm_svm)
print("\nClassification Report - SVM:")
print(classification_report(y_test, pred_svm))

# Naïve Bayes
cm_nb = confusion_matrix(y_test, pred_nb)
print("Confusion Matrix - Naïve Bayes:")
print(cm_nb)
print("\nClassification Report - Naïve Bayes:")
print(classification_report(y_test, pred_nb))

# Decision Tree
cm_dt = confusion_matrix(y_test, pred_dt)
print("Confusion Matrix - Decision Tree:")
print(cm_dt)
print("\nClassification Report - Decision Tree:")
print(classification_report(y_test, pred_dt))

# Random Forest
cm_rf = confusion_matrix(y_test, pred_rf)
print("Confusion Matrix - Random Forest:")
print(cm_rf)
print("\nClassification Report - Random Forest:")
print(classification_report(y_test, pred_rf))

# Neural Networks
cm_nn = confusion_matrix(y_test, pred_nn)
print("Confusion Matrix - Neural Networks:")
print(cm_nn)
print("\nClassification Report - Neural Networks:")
print(classification_report(y_test, pred_nn))

# K-means Clustering
cm_kmeans = confusion_matrix(y_test, pred_kmeans)
print("Confusion Matrix - K-means Clustering:")
print(cm_kmeans)
print("\nClassification Report - K-means Clustering:")
print(classification_report(y_test, pred_kmeans))
# Out:
# Confusion Matrix - Logistic Regression:
# [[18128   164]
#  [  660  1048]]
#
# Classification Report - Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     18292
#            1       0.86      0.61      0.72      1708
#
#     accuracy                           0.96     20000
#    macro avg       0.91      0.80      0.85     20000
# weighted avg       0.96      0.96      0.96     20000
#
# Confusion Matrix - SVM:
# [[18292     0]
#  [ 1053   655]]
#
# Classification Report - SVM:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     18292
#            1       1.00      0.38      0.55      1708
#
#     accuracy                           0.95     20000
#    macro avg       0.97      0.69      0.76     20000
# weighted avg       0.95      0.95      0.94     20000
#
# Confusion Matrix - Naïve Bayes:
# [[17005  1287]
#  [  618  1090]]
#
# ...

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Logistic Regression
cm_lr = confusion_matrix(y_test, pred_lr)
accuracy_lr = (cm_lr[0, 0] + cm_lr[1, 1]) / np.sum(cm_lr) * 100
print("Confusion Matrix - Logistic Regression:")
print(cm_lr)
print("\nClassification Report - Logistic Regression:")
print(classification_report(y_test, pred_lr))
print("C: {:.2f}%".format(accuracy_lr))

# SVM
cm_svm = confusion_matrix(y_test, pred_svm)
accuracy_svm = (cm_svm[0, 0] + cm_svm[1, 1]) / np.sum(cm_svm) * 100
print("Confusion Matrix - SVM:")
print(cm_svm)
print("\nClassification Report - SVM:")
print(classification_report(y_test, pred_svm))
print("Accuracy - SVM: {:.2f}%".format(accuracy_svm))

# Naïve Bayes
cm_nb = confusion_matrix(y_test, pred_nb)
accuracy_nb = (cm_nb[0, 0] + cm_nb[1, 1]) / np.sum(cm_nb) * 100
print("Confusion Matrix - Naïve Bayes:")
print(cm_nb)
print("\nClassification Report - Naïve Bayes:")
print(classification_report(y_test, pred_nb))
print("Accuracy - Naïve Bayes: {:.2f}%".format(accuracy_nb))

# Decision Tree
cm_dt = confusion_matrix(y_test, pred_dt)
accuracy_dt = (cm_dt[0, 0] + cm_dt[1, 1]) / np.sum(cm_dt) * 100
print("Confusion Matrix - Decision Tree:")
print(cm_dt)
print("\nClassification Report - Decision Tree:")
print(classification_report(y_test, pred_dt))
print("Accuracy - Decision Tree: {:.2f}%".format(accuracy_dt))

# Random Forest
cm_rf = confusion_matrix(y_test, pred_rf)
accuracy_rf = (cm_rf[0, 0] + cm_rf[1, 1]) / np.sum(cm_rf) * 100
print("Confusion Matrix - Random Forest:")
print(cm_rf)
print("\nClassification Report - Random Forest:")
print(classification_report(y_test, pred_rf))
print("Accuracy - Random Forest: {:.2f}%".format(accuracy_rf))

# Neural Networks
cm_nn = confusion_matrix(y_test, pred_nn)
accuracy_nn = (cm_nn[0, 0] + cm_nn[1, 1]) / np.sum(cm_nn) * 100
print("Confusion Matrix - Neural Networks:")
print(cm_nn)
print("\nClassification Report - Neural Networks:")
print(classification_report(y_test, pred_nn))
print("Accuracy - Neural Networks: {:.2f}%".format(accuracy_nn))

# K-means Clustering
cm_kmeans = confusion_matrix(y_test, pred_kmeans)
accuracy_kmeans = (cm_kmeans[0, 0] + cm_kmeans[1, 1]) / np.sum(cm_kmeans) * 100
print("Confusion Matrix - K-means Clustering:")
print(cm_kmeans)
print("\nClassification Report - K-means Clustering:")
print(classification_report(y_test, pred_kmeans))
print("Accuracy - K-means Clustering: {:.2f}%".format(accuracy_kmeans))
# Out:
# Confusion Matrix - Logistic Regression:
# [[18128   164]
#  [  660  1048]]
#
# Classification Report - Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     18292
#            1       0.86      0.61      0.72      1708
#
#     accuracy                           0.96     20000
#    macro avg       0.91      0.80      0.85     20000
# weighted avg       0.96      0.96      0.96     20000
#
# C: 95.88%
# Confusion Matrix - SVM:
# [[18292     0]
#  [ 1053   655]]
#
# Classification Report - SVM:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     18292
#            1       1.00      0.38      0.55      1708
#
#     accuracy                           0.95     20000
#    macro avg       0.97      0.69      0.76     20000
# weighted avg       0.95      0.95      0.94     20000
#
# Accuracy - SVM: 94.73%
# Confusion Matrix - Naïve Bayes:
# [[17005  1287]
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

classifiers = ['Logistic Regression', 'SVM', 'Naïve Bayes', 'Decision Tree', 'Random Forest', 'Neural Networks', 'K-means Clustering']
accuracies = [accuracy_lr, accuracy_svm,accuracy_nb, accuracy_dt, accuracy_rf, accuracy_nn, accuracy_kmeans]

plt.figure(figsize=(10, 6))
sns.barplot(x=classifiers, y=accuracies, palette='mako')
plt.title('Classifier Comparison - Accuracy')
plt.xlabel('Classifier')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.ylim(0, 100)
plt.show()
